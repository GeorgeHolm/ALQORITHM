# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the JSON file
with open('dat/QSP_sim_2.json', 'r') as file:
    data = json.load(file)

# Extract the arrays
predictions = np.array(data['y_sim'])
actuals = np.array(data['y_actual'])

# Find the average difference between the actual and simulated
diff = predictions - actuals

print(predictions)
print(actuals)
print(diff)
# Out:
# [-1.         -0.91651514 -0.79372539 -0.64031242 -0.64807407 -0.4472136
#  -0.47958315 -0.3        -0.3        -0.14142136  0.          0.1
#   0.2         0.3         0.4472136   0.51961524  0.55677644  0.76157731
#   0.76811457  0.92736185  1.        ]
# [-0.90929743 -0.97384763 -0.9995736  -0.98544973 -0.93203909 -0.84147098
#  -0.71735609 -0.56464247 -0.38941834 -0.19866933  0.          0.19866933
#   0.38941834  0.56464247  0.71735609  0.84147098  0.93203909  0.98544973
#   0.9995736   0.97384763  0.90929743]
# [-0.09070257  0.05733249  0.20584821  0.34513731  0.28396502  0.39425739
#   0.23777294  0.26464247  0.08941834  0.05724797  0.         -0.09866933
#  -0.18941834 -0.26464247 -0.2701425  -0.32185574 -0.37526265 -0.22387242
#  -0.23145903 -0.04648578  0.09070257]

# %%
phi = []
diffs = []

for i in range(2, 10, 2):

    # Load the JSON file

    f = 'dat/QSP_sim_' + str(i) + '.json'

    with open(f, 'r') as file:
        data = json.load(file)

    # Extract the arrays
    predictions = np.array(data['y_sim'])
    actuals = np.array(data['y_actual'])

    # Find the average difference between the actual and simulated
    diffs.append(np.mean(np.absolute(predictions - actuals)))
    phi.append((i-1)*2 + 1)

print(diffs)
# Out:
# [0.19708740721772106, 0.030637585867369917, 0.018486694728701406, 0.022190651437226063]

# %%
# Verify that values make sense
print(phi)
print(diffs)

plt.scatter(phi, diffs, color='blue', marker='o')

# Add labels and title
plt.xlabel('Circuit depth')
plt.ylabel('Average pointwise error')
plt.title('Average error of simulated estimate for sin(x) using PSA')

plt.xticks(range(3, 16, 1))

# Show the plot
plt.show()
# Out:
# [3, 7, 11, 15]
# [0.19708740721772106, 0.030637585867369917, 0.018486694728701406, 0.022190651437226063]
